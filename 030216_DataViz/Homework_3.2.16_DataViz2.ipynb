# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

sns.set(style="ticks")
# %matplotlib inline
# Out:
# //anaconda/envs/homework/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# //anaconda/envs/homework/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
df = pd.read_csv('../10mountainlion.csv')

# %% [markdown]
# imported the data

# %%
sns.barplot(x="count", y="COUNTY", data=df, color="b")

# %% [markdown]
# started off with the same setup you did in your first chart

# %%
sns.set_color_codes("dark")
sns.barplot(x="count", y="COUNTY", data=df, color="g")
sns.despine(left=True, bottom=True)

# %% [markdown]
# Tried removing everything and making the bars green and dark

# %%
sns.barplot(x="COUNTY", y="count", data=df, color="y")
sns.despine(left=True, bottom=True)

# %% [markdown]
# Switched the axis around and changed the color to yellow

# %%
sns.barplot(x="COUNTY", y="count", data=df, color="y")
sns.despine(left=True,)

# %% [markdown]
# Added the line on the bottom back.

# %% [markdown]
# Of all the charts I think I like the third one the best, however, I would need a way to make the names easier to read because as it is right now the overlapping doesn't work very well. A big problem I'm noticing with these charts is that there's not title so someone seeing this might be confused about what exactly they're looking at. In addition, sightings might be a broad term as there's several different ways mountain lions were spotted in these counties.
